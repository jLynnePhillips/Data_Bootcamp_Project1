# %%
# %load HC-Assco_Infections_cleanup.py
import pandas as pd
HealthCare_Infections = pd.read_csv("Healthcare Associated Infections - Hospital.csv")

# %%
HealthCare_Infections_dropped = HealthCare_Infections.drop('Phone Number', axis = 1)
HealthCare_Infections_CA = HealthCare_Infections_dropped[HealthCare_Infections_dropped["State"] == "CA"]

# %%
HealthCare_Infections_CA.head(5)
# Out:
#       Provider ID  \
# 9648        50002
# 9649        50002
# 9650        50002
# 9651        50002
# 9652        50002
#
#          Hospital Name  \
# 9648  ST ROSE HOSPITAL
# 9649  ST ROSE HOSPITAL
# 9650  ST ROSE HOSPITAL
# 9651  ST ROSE HOSPITAL
# 9652  ST ROSE HOSPITAL
#
#                  Address  \
# 9648  27200 CALAROGA AVE
# 9649  27200 CALAROGA AVE
# 9650  27200 CALAROGA AVE
# 9651  27200 CALAROGA AVE
# 9652  27200 CALAROGA AVE
#
#          City  \
# 9648  HAYWARD
# 9649  HAYWARD
# 9650  HAYWARD
# 9651  HAYWARD
# 9652  HAYWARD
#
#      State  \
# 9648    CA
# 9649    CA
# 9650    CA
# 9651    CA
# 9652    CA
#
#       ZIP Code  \
# 9648     94545
# 9649     94545
# 9650     94545
# 9651     94545
# 9652     94545
#
#      County Name  \
# 9648     ALAMEDA
# 9649     ALAMEDA
# 9650     ALAMEDA
# 9651     ALAMEDA
# 9652     ALAMEDA
#
#                         Measure Name  \
# 9648  CLABSI: Lower Confidence Limit
# 9649  CLABSI: Upper Confidence Limit
# ...

# %%
HealthCare_Infections_CA = HealthCare_Infections_CA[HealthCare_Infections_CA["Measure ID"].str.contains("_SIR")]

# %%
HealthCare_Infections_CA["Measure Name"].unique()
# Out:
# array([ 'Central line-associated bloodstream infections (CLABSI) in ICUs and select wards',
#        'Catheter-associated urinary tract infections (CAUTI) in ICUs and select wards',
#        'Surgical site infections (SSI) from colon surgery',
#        'Surgical site infections (SSI) from abdominal hysterectomy',
#        'Methicillin-resistant Staphylococcus Aureus (MRSA) blood infections',
#        'Clostridium difficile (C.diff.) intestinal infections'], dtype=object)

# %%
HealthCare_Infections_CA.to_csv("HCI.csv")

# %%
HealthCare_Infections_CA[HealthCare_Infections_CA["Measure ID"] == "HAI_1_SIR"]["City"].nunique()
# Out:
# 230

# %%
City_HAI_2 = HealthCare_Infections_CA[HealthCare_Infections_CA["Measure ID"] == "HAI_2_SIR"]["City"].unique()

# %%
len(City_HAI_2)
# Out:
# 230

# %%
# %load complications_df.py
import pandas as pd
import numpy as np
import csv
csvpath = "Complications and Deaths - Hospital.csv"
complications_original_df=pd.read_csv(csvpath)
del complications_original_df["Address"]
del complications_original_df["Phone Number"]
complications_df = complications_original_df.loc[complications_original_df["State"]=="CA",:]

# %%
complications_df
# Out:
#        Provider ID  \
# 5092         50002
# 5093         50002
# 5094         50002
# 5095         50002
# 5096         50002
# 5097         50002
# 5098         50002
# 5099         50002
# 5100         50002
# 5101         50002
# 5102         50002
# 5103         50002
# 5104         50002
# 5105         50002
# 5106         50002
# 5107         50002
# 5108         50002
# 5109         50002
# 5110         50002
# 5111         50006
# 5112         50006
# 5113         50006
# 5114         50006
# 5115         50006
# 5116         50006
# 5117         50006
# 5118         50006
# 5119         50006
# 5120         50006
# 5121         50006
# ...            ...
# 11560        53310
# 11561        53310
# 11562        53310
# 11563        53310
# 11564        53310
# 11565        53310
# 11566        53310
# 11567        53310
# 11568        53310
# 11569        53310
# 11570        53310
# 11571        53311
# 11572        53311
# 11573        53311
# 11574        53311
# ...

# %% [markdown]
#        'Central line-associated bloodstream infections (CLABSI) in ICUs and select wards',
#        'Catheter-associated urinary tract infections (CAUTI) in ICUs and select wards',
#        'Surgical site infections (SSI) from colon surgery',
#        'Surgical site infections (SSI) from abdominal hysterectomy',
#        'Methicillin-resistant Staphylococcus Aureus (MRSA) blood infections',
#        'Clostridium difficile (C.diff.) intestinal infections'], dtype=object)

# %%
if complications_df["City"].all() == HealthCare_Infections_CA["City"].all():
    print ("Identical Cities")
# Out:
# Identical Cities

# %%
complications_df[complications_df["Measure Name"] == 'Rate of complications for hip/knee replacement patients']["City"].nunique()
# Out:
# 230

# %%
complications_df_HAI = complications_df[complications_df["Measure ID"].str.contains("HAI")]
complications_df_HAI
# Out:
# Empty DataFrame
# Columns: [Provider ID, Hospital Name, City, State, ZIP Code, County Name, Measure Name, Measure ID, Compared to National, Denominator, Score, Lower Estimate, Higher Estimate, Footnote, Measure Start Date, Measure End Date]
# Index: []

# %%
#county_data = complications_df.groupby(["County Name", "Measure Name", "City"])
county_data = pd.DataFrame(complications_df.groupby(["County Name", "Measure Name", "City"]).size().reset_index(name = "Group_Count"))

# %%
HealthCare_Infections_CA.groupby(["County Name", "Measure Name", "City"])["City"].count()
# Out:
# County Name  Measure Name                                                                      City
# ALAMEDA      Catheter-associated urinary tract infections (CAUTI) in ICUs and select wards     ALAMEDA          1
#                                                                                                BERKELEY         1
#                                                                                                CASTRO VALLEY    1
#                                                                                                FREMONT          2
#                                                                                                HAYWARD          1
#                                                                                                OAKLAND          4
#                                                                                                PLEASANTON       1
# ...

# %%
complications_Fremont = complications_df[complications_df["City"] == "FREMONT"]

# %%
complications_Fremont[complications_Fremont["Measure ID"]== "PSI_14_POSTOP_DEHIS"]
# Out:
#       Provider ID  \
# 6908        50195
# 8827        50512
#
#                              Hospital Name  \
# 6908                   WASHINGTON HOSPITAL
# 8827  KAISER FOUNDATION HOSPITAL - FREMONT
#
#          City  \
# 6908  FREMONT
# 8827  FREMONT
#
#      State  \
# 6908    CA
# 8827    CA
#
#       ZIP Code  \
# 6908     94538
# 8827     94538
#
#      County Name  \
# 6908     ALAMEDA
# 8827     ALAMEDA
#
#                                            Measure Name  \
# 6908  A wound that splits open  after surgery on the...
# 8827  A wound that splits open  after surgery on the...
#
#                Measure ID  \
# 6908  PSI_14_POSTOP_DEHIS
# 8827  PSI_14_POSTOP_DEHIS
#
#                      Compared to National  \
# 6908  No Different than the National Rate
# 8827            Number of Cases Too Small
#
#         Denominator  \
# 6908            102
# 8827  Not Available
#
#               Score  \
# 6908           2.74
# 8827  Not Available
#
#      Lower Estimate  \
# ...
