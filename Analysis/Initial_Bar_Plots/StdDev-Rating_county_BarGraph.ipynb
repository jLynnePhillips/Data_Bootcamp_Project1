# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
StdDev_ratings_pd = pd.read_csv("StdDev_Overall_Ratings_perCounty.csv")
StdDev_ratings_pd[StdDev_ratings_pd["County Name"] == "MERCED"]
# Out:
#    County Name  Std_Dev_Overall_Rating
# 12      MERCED                     0.0

# %%
StdDev_ratings_pd.plot(kind = 'bar', figsize=(20,5))

# %%
x_axis = np.arange(len(StdDev_ratings_pd))
ticks_location = [value for value in x_axis]
plt.xticks(ticks_location, StdDev_ratings_pd["County Name"])
plt.show()
