# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
# get data file "Hospital Ratings Merged.csv", 
# cleaned up to delete the two additional index columns (unnamed :0 and unnamed :0_x) created
# probably because of creating the cleaned up csv's from original data sets with out setting the index to False.
Hospital_Merged_pd = pd.read_csv("Hospital Ratings Merged.csv")
Hospital_Merged_pd = Hospital_Merged_pd.drop('Unnamed: 0', axis = 1)
Hospital_Merged_pd.to_csv("Hospital_Merged_CleanNoIndex.csv", index = False)
Hospital_Merged_pd.head()
# Out:
#    Provider ID Cleanliness Nurse_com Doc_com Staff_responsiveness  \
# 0        50002           2         2       2                    2
# 1        50006           2         2       2                    2
# 2        50007           3         4       3                    3
# 3        50008           2         2       3                    2
# 4        50009           2         3       3                    3
#
#   Pain_management Comm_medicine Discharge_info Care_transition  \
# 0               2             2              2               1
# 1               3             2              3               2
# 2               4             3              3               4
# 3               3             2              2               2
# 4               3             3              3               2
#
#   Overall_Hos_Rating               ...               Summary_star  \
# 0                  2               ...                          2
# ...
