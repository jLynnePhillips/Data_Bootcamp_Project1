# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
mean_ratings_pd = pd.read_csv("Mean_Overall_Ratings_perCounty.csv")

# %%
mean_ratings_pd.plot(kind = 'bar', figsize = (25,5))

# %%
x_axis = np.arange(len(mean_ratings_pd))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, mean_ratings_pd["County Name"])
plt.savefig("MeanRating_County.png")
plt.show()
